# %% [markdown]
# ![데이터프레임 예시.png](data:image/png;base64,...)

# %% [markdown]
# 1) 위와 같이 표가 나오도록 데이터 프레임을 완성하시오.

# %%
import pandas as pd
#데이터 프레임 항목 구성하기
df = pd.DataFrame(_____________________________________________________________)
display(df)
# Out:
#     국어   영어    수학  과학  사회
# 0  100  100  70.0  60  90
# 1   70   70  99.0  98  90
# 2   97   97   NaN  90  89
# 3   89   60  90.0  60  80
# 4  100   99  90.0  88  90

# %%
#이름이란 컬럼을 추가하기
df[___] = [__________________________]
display(df)
# Out:
#     국어   영어    수학  과학  사회   이름
# 0  100  100  70.0  60  90  홍길동
# 1   70   70  99.0  98  90  김길동
# 2   97   97   NaN  90  89  박길동
# 3   89   60  90.0  60  80  최길동
# 4  100   99  90.0  88  90  이길동

# %%
# 원하는 순서대로 컬럼 재정렬
df = df[[_________________________________________]]
display(df)
# Out:
#     이름   국어   영어    수학  과학  사회
# 0  홍길동  100  100  70.0  60  90
# 1  김길동   70   70  99.0  98  90
# 2  박길동   97   97   NaN  90  89
# 3  최길동   89   60  90.0  60  80
# 4  이길동  100   99  90.0  88  90

# %% [markdown]
# 2) 결측치를 찾아서 0으로 채우시오.

# %%
# 결측치가 있는 컬럼만 골라서 0으로 채움
df[df.columns[df.isnull().any()]] = df[df.columns[df.isnull().any()]].______
display(df)
# Out:
#     이름   국어   영어    수학  과학  사회
# 0  홍길동  100  100  70.0  60  90
# 1  김길동   70   70  99.0  98  90
# 2  박길동   97   97   0.0  90  89
# 3  최길동   89   60  90.0  60  80
# 4  이길동  100   99  90.0  88  90
